# %%
# !pip list
# Out:
# Package                  Version
# ------------------------ ------------
# absl-py                  0.8.0
# altair                   3.2.0
# apache-beam              2.18.0
# asn1crypto               1.0.1
# astor                    0.8.0
# astroid                  2.3.1
# atomicwrites             1.4.0
# attrs                    19.2.0
# audioread                2.1.8
# avro-python3             1.9.2.1
# backcall                 0.1.0
# backports.tempfile       1.0
# backports.weakref        1.0.post1
# beautifulsoup4           4.9.1
# bleach                   3.1.0
# bokeh                    2.0.2
# boto                     2.49.0
# boto3                    1.9.234
# botocore                 1.12.234
# branca                   0.3.1
# bz2file                  0.98
# cachetools               3.1.1
# certifi                  2020.6.20
# cffi                     1.12.3
# chardet                  3.0.4
# Click                    7.0
# click-plugins            1.1.1
# ...

# %% [markdown]
# beautifulsoup4           4.9.1     -> 4.6.0
# nltk                     3.4.5
